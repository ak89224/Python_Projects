# %%
import pandas

# %%
import os
os.listdir()
# Out:
# ['supermarkets.json',
#  'supermarkets-semi-colons.txt',
#  'supermarkets-commas.txt',
#  '.ipynb_checkpoints',
#  'supermarkets.csv',
#  'supermarkets-semi-colons_Raw.txt',
#  'supermarkets.xlsx',
#  'Pandas_101.ipynb']

# %%
df5=pandas.read_json("./supermarkets.json")
df5
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
loc=nom.geocode("3995 23rd St, San Francisco California 94114")

# %%
loc.latitude
# Out:
# 37.75298458728149

# %%
df5
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df5.rename(columns={"Address":"Locality"},inplace=True)
df5
# Out:
#           Locality           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df5["Address"]=df5["Locality"]+", "+df5["City"]+", "+df5["State"]+", "+df5["Country"]

# %%
df5
# Out:
#            Locality           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees                                            Address
# ID
# 1           8         3666 21st St, San Francisco, CA 94114, USA
# 2          15       735 Dolores St, San Francisco, CA 94119, USA
# 3          25  332 Hill St, San Francisco, California 94114, USA
# 4          10         3995 23rd St, San Francisco, CA 94114, USA
# 5          12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df5["Coordinates"]=df5["Address"].apply(nom.geocode)

# %%
df5
# Out:
#           Locality           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State                                            Address  \
# 0          CA 94114         3666 21st St, San Francisco, CA 94114, USA
# 1          CA 94119       735 Dolores St, San Francisco, CA 94119, USA
# 2  California 94114  332 Hill St, San Francisco, California 94114, USA
# 3          CA 94114         3995 23rd St, San Francisco, CA 94114, USA
# 4        California    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df5.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df5.Coordinates[1]
# Out:
# Location(735 Dolores St, San Francisco, California, 94110, (37.75780079156327, -122.4255989188067, 0.0))

# %%
df5.Coordinates[1].latitude
# Out:
# 37.75780079156327

# %%
df5["Latitude"]=df5["Coordinates"].apply(lambda x: x.latitude if x != None else None)

# %%
df5
# Out:
#           Locality           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State                                            Address  \
# 0          CA 94114         3666 21st St, San Francisco, CA 94114, USA
# 1          CA 94119       735 Dolores St, San Francisco, CA 94119, USA
# 2  California 94114  332 Hill St, San Francisco, California 94114, USA
# 3          CA 94114         3995 23rd St, San Francisco, CA 94114, USA
# 4        California    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df5["Longitude"]=df5["Coordinates"].apply(lambda x: x.longitude if x != None else None)

# %%
df5
# Out:
#           Locality           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State                                            Address  \
# 0          CA 94114         3666 21st St, San Francisco, CA 94114, USA
# 1          CA 94119       735 Dolores St, San Francisco, CA 94119, USA
# 2  California 94114  332 Hill St, San Francisco, California 94114, USA
# 3          CA 94114         3995 23rd St, San Francisco, CA 94114, USA
# 4        California    1056 Sanchez St, San Francisco, California, USA
# ...
