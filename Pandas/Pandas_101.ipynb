# %%
import pandas

# %%
df1=pandas.DataFrame([[1,2,3,4],[9,8,7,6]])

# %%
print (df1)
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  9  8  7  6

# %%
df2=pandas.DataFrame([[1,2,3,4],[9,8,7,6]],columns=["A","B","C","D"])
df2
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  9  8  7  6

# %%
df3=pandas.DataFrame([[1,2,3,4],[9,8,7,6]],columns=["A","B","C","D"],index=["First","Second"])
df3
# Out:
#         A  B  C  D
# First   1  2  3  4
# Second  9  8  7  6

# %%
import os
os.listdir()
# Out:
# ['supermarkets.json',
#  'supermarkets-semi-colons.txt',
#  'supermarkets-commas.txt',
#  '.ipynb_checkpoints',
#  'supermarkets.csv',
#  'supermarkets-semi-colons_Raw.txt',
#  'supermarkets.xlsx',
#  'GeoLocation_Finder.ipynb',
#  'Pandas_101.ipynb']

# %%
df4=pandas.read_csv("./supermarkets.csv")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_json("./supermarkets.json")
df5
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df6=pandas.read_excel("./supermarkets.xlsx")
df6
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df7=pandas.read_excel("./supermarkets.xlsx",sheet_name=0)
df7
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df8=pandas.read_csv("./supermarkets-commas.txt")
df8
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df9=pandas.read_csv("./supermarkets-semi-colons.txt")
df9
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
df10=pandas.read_csv("./supermarkets-semi-colons.txt",sep=";")
df10
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pandas.read_csv?

# %%
os.listdir()
# Out:
# ['supermarkets.json',
#  'supermarkets-semi-colons.txt',
#  'supermarkets-commas.txt',
#  '.ipynb_checkpoints',
#  'supermarkets.csv',
#  'supermarkets-semi-colons_Raw.txt',
#  'supermarkets.xlsx',
#  'GeoLocation_Finder.ipynb',
#  'Pandas_101.ipynb']

# %%
df11=pandas.read_csv("./supermarkets-semi-colons_Raw.txt",sep=";",header=None)
df11
# Out:
#    0                1              2                 3    4             5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA       Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA   Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA   Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA    Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA       Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA    Richvalley  20

# %%
df11.columns = ["ID","Address","City","State","Country","Name","Employees"]
df11
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df11.set_index("ID")
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df11
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df12=df11.set_index("ID")
df12
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df11.set_index("ID", inplace=True)

# %%
df11
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df11.set_index("Address", inplace=True)
df11
# Out:
#                           City             State Country          Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       Madeira
# 735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St      San Francisco  California 94114     USA   Super River
# 3995 23rd St     San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df11.set_index("Name", inplace=True, drop=False)
df11
# Out:
#                        City             State Country          Name  Employees
# Name
# Madeira       San Francisco          CA 94114     USA       Madeira          8
# Bready Shop   San Francisco          CA 94119     USA   Bready Shop         15
#  Super River  San Francisco  California 94114     USA   Super River         25
# Ben's Shop    San Francisco          CA 94114     USA    Ben's Shop         10
# Sanchez       San Francisco        California     USA       Sanchez         12
# Richvalley    San Francisco          CA 94114     USA    Richvalley         20

# %%
df11.set_index("Employees", inplace=False, drop=False)
# Out:
#                     City             State Country          Name  Employees
# Employees
# 8          San Francisco          CA 94114     USA       Madeira          8
# 15         San Francisco          CA 94119     USA   Bready Shop         15
# 25         San Francisco  California 94114     USA   Super River         25
# 10         San Francisco          CA 94114     USA    Ben's Shop         10
# 12         San Francisco        California     USA       Sanchez         12
# 20         San Francisco          CA 94114     USA    Richvalley         20

# %%
df11
# Out:
#                       City       State Country         Name  Employees  \
# Name
# Madeira      San Francisco    CA 94114     USA      Madeira          8
# Bready Shop  San Francisco    CA 94119     USA  Bready Shop         15
# Ben's Shop   San Francisco    CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco  California     USA      Sanchez         12
# Richvalley   San Francisco    CA 94114     USA   Richvalley         20
#
#                      Continent
# Name
# Madeira      USA,North America
# Bready Shop  USA,North America
# Ben's Shop   USA,North America
# Sanchez      USA,North America
# Richvalley   USA,North America

# %%
df11.loc["Bready Shop":"Ben's Shop","City":"Country"]
# Out:
#                       City     State Country
# Name
# Bready Shop  San Francisco  CA 94119     USA
# Ben's Shop   San Francisco  CA 94114     USA

# %%
df11.loc["Bready Shop":"Ben's Shop","Country"]
# Out:
# Name
# Bready Shop     USA
#  Super River    USA
# Ben's Shop      USA
# Name: Country, dtype: object

# %%
df11.loc[:,"State"]
# Out:
# Name
# Madeira                 CA 94114
# Bready Shop             CA 94119
#  Super River    California 94114
# Ben's Shop              CA 94114
# Sanchez               California
# Richvalley              CA 94114
# Name: State, dtype: object

# %%
list(df11.loc[:,"State"])
# Out:
# ['CA 94114',
#  'CA 94119',
#  'California 94114',
#  'CA 94114',
#  'California',
#  'CA 94114']

# %%
df11
# Out:
#                       City       State Country         Name  Employees  \
# Name
# Madeira      San Francisco    CA 94114     USA      Madeira          8
# Bready Shop  San Francisco    CA 94119     USA  Bready Shop         15
# Ben's Shop   San Francisco    CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco  California     USA      Sanchez         12
# Richvalley   San Francisco    CA 94114     USA   Richvalley         20
#
#                      Continent
# Name
# Madeira      USA,North America
# Bready Shop  USA,North America
# Ben's Shop   USA,North America
# Sanchez      USA,North America
# Richvalley   USA,North America

# %%
df11.iloc[:,0:3]
# Out:
#                        City             State Country
# Name
# Madeira       San Francisco          CA 94114     USA
# Bready Shop   San Francisco          CA 94119     USA
#  Super River  San Francisco  California 94114     USA
# Ben's Shop    San Francisco          CA 94114     USA
# Sanchez       San Francisco        California     USA
# Richvalley    San Francisco          CA 94114     USA

# %%
df11.iloc[4,:]
# Out:
# City         San Francisco
# State           California
# Country                USA
# Name               Sanchez
# Employees               12
# Name: Sanchez, dtype: object

# %%
df11.drop("City",1)
# Out:
#                          State Country          Name  Employees
# Name
# Madeira               CA 94114     USA       Madeira          8
# Bready Shop           CA 94119     USA   Bready Shop         15
#  Super River  California 94114     USA   Super River         25
# Ben's Shop            CA 94114     USA    Ben's Shop         10
# Sanchez             California     USA       Sanchez         12
# Richvalley            CA 94114     USA    Richvalley         20

# %%
df11
# Out:
#                        City             State Country          Name  Employees
# Name
# Madeira       San Francisco          CA 94114     USA       Madeira          8
# Bready Shop   San Francisco          CA 94119     USA   Bready Shop         15
#  Super River  San Francisco  California 94114     USA   Super River         25
# Ben's Shop    San Francisco          CA 94114     USA    Ben's Shop         10
# Sanchez       San Francisco        California     USA       Sanchez         12
# Richvalley    San Francisco          CA 94114     USA    Richvalley         20

# %%
df11=df11.drop(" Super River",0)

# %%
df11
# Out:
#                       City       State Country         Name  Employees
# Name
# Madeira      San Francisco    CA 94114     USA      Madeira          8
# Bready Shop  San Francisco    CA 94119     USA  Bready Shop         15
# Ben's Shop   San Francisco    CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco  California     USA      Sanchez         12
# Richvalley   San Francisco    CA 94114     USA   Richvalley         20

# %%
df11.drop(df11.index[0:3],0)
# Out:
#                      City       State Country        Name  Employees
# Name
# Sanchez     San Francisco  California     USA     Sanchez         12
# Richvalley  San Francisco    CA 94114     USA  Richvalley         20

# %%
df11.drop(df11.columns[-2],1)
# Out:
#                       City       State Country  Employees
# Name
# Madeira      San Francisco    CA 94114     USA          8
# Bready Shop  San Francisco    CA 94119     USA         15
# Ben's Shop   San Francisco    CA 94114     USA         10
# Sanchez      San Francisco  California     USA         12
# Richvalley   San Francisco    CA 94114     USA         20

# %%
df11.shape
# Out:
# (5, 5)

# %%
df11.shape[0]
# Out:
# 5

# %%
df11["Continent"]=df11.shape[0]*["North America"]

# %%
df11
# Out:
#                       City       State Country         Name  Employees  \
# Name
# Madeira      San Francisco    CA 94114     USA      Madeira          8
# Bready Shop  San Francisco    CA 94119     USA  Bready Shop         15
# Ben's Shop   San Francisco    CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco  California     USA      Sanchez         12
# Richvalley   San Francisco    CA 94114     USA   Richvalley         20
#
#                  Continent
# Name
# Madeira      North America
# Bready Shop  North America
# Ben's Shop   North America
# Sanchez      North America
# Richvalley   North America

# %%
df11["Continent"]=df11["Country"] + "," + "North America"

# %%
df11
# Out:
#                       City       State Country         Name  Employees  \
# Name
# Madeira      San Francisco    CA 94114     USA      Madeira          8
# Bready Shop  San Francisco    CA 94119     USA  Bready Shop         15
# Ben's Shop   San Francisco    CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco  California     USA      Sanchez         12
# Richvalley   San Francisco    CA 94114     USA   Richvalley         20
#
#                      Continent
# Name
# Madeira      USA,North America
# Bready Shop  USA,North America
# Ben's Shop   USA,North America
# Sanchez      USA,North America
# Richvalley   USA,North America

# %%
df11_t=df11.T

# %%
df11_t
# Out:
# Name                 Madeira        Bready Shop         Ben's Shop  \
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# Name                 Sanchez         Richvalley
# City           San Francisco      San Francisco
# State             California           CA 94114
# Country                  USA                USA
# Name                 Sanchez         Richvalley
# Employees                 12                 20
# Continent  USA,North America  USA,North America

# %%
df12
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df12.replace(" Super River","Super River")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df12.loc[df12.Name == " Super River","Employees"]
# Out:
# ID
# 3    25
# Name: Employees, dtype: int64

# %%
df12.replace(" Super River","Super River", inplace=True)

# %%
df12
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df12.loc[df12.Name == "Super River","Employees"]
# Out:
# ID
# 3    25
# Name: Employees, dtype: int64

# %%
df12
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df12.columns
# Out:
# Index(['Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df12_x=df12.rename(columns=lambda x: x+"_X",inplace=False)

# %%
df12_y=df12.rename(columns=lambda x: x+"_Y",inplace=False)

# %%
df12_x
# Out:
#           Address_X         City_X           State_X Country_X       Name_X  \
# ID
# 1      3666 21st St  San Francisco          CA 94114       USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119       USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114       USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114       USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California       USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114       USA   Richvalley
#
#     Employees_X
# ID
# 1             8
# 2            15
# 3            25
# 4            10
# 5            12
# 6            20

# %%
df12_y
# Out:
#           Address_Y         City_Y           State_Y Country_Y       Name_Y  \
# ID
# 1      3666 21st St  San Francisco          CA 94114       USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119       USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114       USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114       USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California       USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114       USA   Richvalley
#
#     Employees_Y
# ID
# 1             8
# 2            15
# 3            25
# 4            10
# 5            12
# 6            20

# %%
df12_x.join(df12_y)
# Out:
#           Address_X         City_X           State_X Country_X       Name_X  \
# ID
# 1      3666 21st St  San Francisco          CA 94114       USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119       USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114       USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114       USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California       USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114       USA   Richvalley
#
#     Employees_X        Address_Y         City_Y           State_Y Country_Y  \
# ID
# 1             8     3666 21st St  San Francisco          CA 94114       USA
# 2            15   735 Dolores St  San Francisco          CA 94119       USA
# 3            25      332 Hill St  San Francisco  California 94114       USA
# 4            10     3995 23rd St  San Francisco          CA 94114       USA
# ...

# %%
df13=df12.rename(columns=lambda x: x+"_X",inplace=False).join(df12.rename(columns=lambda x: x+"_Y",inplace=False))

# %%
df13
# Out:
#           Address_X         City_X           State_X Country_X       Name_X  \
# ID
# 1      3666 21st St  San Francisco          CA 94114       USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119       USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114       USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114       USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California       USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114       USA   Richvalley
#
#     Employees_X        Address_Y         City_Y           State_Y Country_Y  \
# ID
# 1             8     3666 21st St  San Francisco          CA 94114       USA
# 2            15   735 Dolores St  San Francisco          CA 94119       USA
# 3            25      332 Hill St  San Francisco  California 94114       USA
# 4            10     3995 23rd St  San Francisco          CA 94114       USA
# ...

# %%
df14=df12_x.append(df12_x)

# %%
df14
# Out:
#           Address_X         City_X           State_X Country_X       Name_X  \
# ID
# 1      3666 21st St  San Francisco          CA 94114       USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119       USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114       USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114       USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California       USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114       USA   Richvalley
# 1      3666 21st St  San Francisco          CA 94114       USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119       USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114       USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114       USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California       USA      Sanchez
# ...

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
loc=nom.geocode("3995 23rd St, San Francisco California 94114")

# %%
loc.latitude
# Out:
# 37.75298458728149

# %%
df12
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df12.rename(columns={"Address":"Locality"},inplace=True)
df12
# Out:
#            Locality           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df12["Address"]=df12["Locality"]+", "+df12["City"]+", "+df12["State"]+", "+df12["Country"]

# %%
df12
# Out:
#            Locality           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees                                            Address
# ID
# 1           8         3666 21st St, San Francisco, CA 94114, USA
# 2          15       735 Dolores St, San Francisco, CA 94119, USA
# 3          25  332 Hill St, San Francisco, California 94114, USA
# 4          10         3995 23rd St, San Francisco, CA 94114, USA
# 5          12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df12["Coordinates"]=df12["Address"].apply(nom.geocode)

# %%
df12
# Out:
#            Locality           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees                                            Address  \
# ID
# 1           8         3666 21st St, San Francisco, CA 94114, USA
# 2          15       735 Dolores St, San Francisco, CA 94119, USA
# 3          25  332 Hill St, San Francisco, California 94114, USA
# 4          10         3995 23rd St, San Francisco, CA 94114, USA
# 5          12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df12.Coordinates
# Out:
# ID
# 1    (3666 21st St, San Francisco, California, 9411...
# 2    (735 Dolores St, San Francisco, California, 94...
# 3    (332 Hill St, San Francisco, California, 94114...
# 4    (3995 23rd St, San Francisco, California, 9411...
# 5    (1056 Sanchez St, San Francisco, California, 9...
# 6    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df12.Coordinates[1]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.75644449321933, -122.42935314363206, 0.0))

# %%
df12.Coordinates[1].latitude
# Out:
# 37.75644449321933

# %%
df12["Latitude"]=df12["Coordinates"].apply(lambda x: x.latitude if x != None else None)

# %%
df12
# Out:
#            Locality           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees                                            Address  \
# ID
# 1           8         3666 21st St, San Francisco, CA 94114, USA
# 2          15       735 Dolores St, San Francisco, CA 94119, USA
# 3          25  332 Hill St, San Francisco, California 94114, USA
# 4          10         3995 23rd St, San Francisco, CA 94114, USA
# 5          12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df12["Longitude"]=df12["Coordinates"].apply(lambda x: x.longitude if x != None else None)

# %%
df12
# Out:
#            Locality           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees                                            Address  \
# ID
# 1           8         3666 21st St, San Francisco, CA 94114, USA
# 2          15       735 Dolores St, San Francisco, CA 94119, USA
# 3          25  332 Hill St, San Francisco, California 94114, USA
# 4          10         3995 23rd St, San Francisco, CA 94114, USA
# 5          12    1056 Sanchez St, San Francisco, California, USA
# ...
